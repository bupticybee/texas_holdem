# %%
import os
import sys

sys.path.append('../../opensources/Two-Card-Poker-CFR-AI/')

from cfr import CFR
# %load_ext autoreload
# %autoreload 2

# %load_ext line_profiler
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler

# %%
import random 
random.seed(13)

cfr = CFR()
ante = 1.0
bet1 = 2.0
bet2 = 8.0

#util = cfr.train(40000000, ante, bet1, bet2)

# %%
    BET = '0'
    CALL = '1'
    CHECK = '2'
    FOLD = '3'

# %%
# %lprun -f cfr.train util = cfr.train(50000, ante, bet1, bet2)
# Out:
# Ante: 1.000000   Bet-1: 2.000000   Bet-2: 8.000000
# P1 expected value after 1000 iterations: -0.003613
# P1 expected value after 2000 iterations: -0.029539
# P1 expected value after 3000 iterations: -0.012721
# P1 expected value after 4000 iterations: -0.016599
# P1 expected value after 5000 iterations: -0.046618
# P1 expected value after 6000 iterations: -0.038662
# P1 expected value after 7000 iterations: -0.046030
# P1 expected value after 8000 iterations: -0.060049
# P1 expected value after 9000 iterations: -0.055183
# P1 expected value after 10000 iterations: -0.055420
# P1 expected value after 11000 iterations: -0.051939
# P1 expected value after 12000 iterations: -0.053370
# P1 expected value after 13000 iterations: -0.049562
# P1 expected value after 14000 iterations: -0.049944
# P1 expected value after 15000 iterations: -0.049664
# P1 expected value after 16000 iterations: -0.056394
# P1 expected value after 17000 iterations: -0.051591
# ...

# %%
# %lprun -f cfr.cfr util = cfr.train(50000, ante, bet1, bet2)
# Out:
# Ante: 1.000000   Bet-1: 2.000000   Bet-2: 8.000000
# P1 expected value after 1000 iterations: -0.049843
# P1 expected value after 2000 iterations: -0.069863
# P1 expected value after 3000 iterations: -0.072671
# P1 expected value after 4000 iterations: -0.031649
# P1 expected value after 5000 iterations: -0.040627
# P1 expected value after 6000 iterations: -0.047299
# P1 expected value after 7000 iterations: -0.045958
# P1 expected value after 8000 iterations: -0.053197
# P1 expected value after 9000 iterations: -0.052617
# P1 expected value after 10000 iterations: -0.062345
# P1 expected value after 11000 iterations: -0.066385
# P1 expected value after 12000 iterations: -0.064309
# P1 expected value after 13000 iterations: -0.070600
# P1 expected value after 14000 iterations: -0.074299
# P1 expected value after 15000 iterations: -0.071397
# P1 expected value after 16000 iterations: -0.075969
# P1 expected value after 17000 iterations: -0.076327
# ...
